# %% [markdown]
# # Reports

# %%
import os
from datetime import date

import pandas as pd
import matplotlib.pyplot as plt

# So plots show inline in Jupyter
# %matplotlib inline

AWS_PROFILE = "de_jay_east"
REGION = "us-east-1"

LANDING_BUCKET = "dq-landing-657082399901-dev"
PROCESSED_BUCKET = "dq-processed-657082399901-dev"
ANALYTICS_BUCKET = "dq-analytics-657082399901-dev"

# If you're using awscli profile, configure env for s3fs/boto
os.environ["AWS_PROFILE"] = AWS_PROFILE
os.environ["AWS_DEFAULT_REGION"] = REGION

today = date.today().isoformat()
today
# Out:
# '2025-12-19'

# %%
import pandas as pd

ts_path = f"s3://{PROCESSED_BUCKET}/processed/bls/time_series_pr/"
pop_path = f"s3://{PROCESSED_BUCKET}/processed/population/population_us/"

df_ts = pd.read_parquet(
    ts_path,
    engine="pyarrow",
    dtype_backend="pyarrow",   # <-- key part
)

df_pop = pd.read_parquet(
    pop_path,
    engine="pyarrow",
    dtype_backend="pyarrow",
)

df_ts.head(), df_ts.dtypes
# Out:
# (     series_id period   value  year
#  0  PRS84006012    Q02    -1.4  1947
#  1  PRS84006012    Q03     4.6  1947
#  2  PRS84006012    Q04     3.6  1947
#  3  PRS84006013    Q01  42.414  1947
#  4  PRS84006013    Q02   42.26  1947,
#  series_id                                      string[pyarrow]
#  period                                         string[pyarrow]
#  value                                          double[pyarrow]
#  year         dictionary<values=int32, indices=int32, ordere...
#  dtype: object)

# %%
df_pop.head(), df_pop.dtypes
# Out:
# (   population  year
#  0   316128839  2013
#  1   318857056  2014
#  2   321418821  2015
#  3   323127515  2016
#  4   325719178  2017,
#  population                                       int64[pyarrow]
#  year          dictionary<values=int32, indices=int32, ordere...
#  dtype: object)

# %%
import s3fs

fs = s3fs.S3FileSystem(profile=AWS_PROFILE)
run_date = "2025-11-24"  # or whatever date you want

best_prefix = (
    f"{ANALYTICS_BUCKET}/analytics/reports/"
    f"run_date={run_date}/report_best_year.csv/"
)
joined_prefix = (
    f"{ANALYTICS_BUCKET}/analytics/reports/"
    f"run_date={run_date}/report_joined.csv/"
)

print("Best year prefix:", best_prefix)
print("Joined prefix:", joined_prefix)

best_files = fs.ls(best_prefix)
joined_files = fs.ls(joined_prefix)

best_files, joined_files
# Out:
# Best year prefix: dq-analytics-657082399901-dev/analytics/reports/run_date=2025-11-24/report_best_year.csv/
# Joined prefix: dq-analytics-657082399901-dev/analytics/reports/run_date=2025-11-24/report_joined.csv/
# (['dq-analytics-657082399901-dev/analytics/reports/run_date=2025-11-24/report_best_year.csv/part-00000-73cc26d7-af8b-40b9-b9d1-6e3f028dfd54-c000.csv'],
#  ['dq-analytics-657082399901-dev/analytics/reports/run_date=2025-11-24/report_joined.csv/part-00000-4ebb808b-43d8-4436-a90c-1b3e7a8b172a-c000.csv'])

# %%
def read_csv_partitioned(file_list):
    dfs = []
    for fpath in file_list:
        print("Reading", fpath)
        dfs.append(pd.read_csv("s3://" + fpath))
    return pd.concat(dfs, ignore_index=True)

df_best = read_csv_partitioned(best_files)
df_joined = read_csv_partitioned(joined_files)

df_best.head(), df_joined.head()
# Out:
# Reading dq-analytics-657082399901-dev/analytics/reports/run_date=2025-11-24/report_best_year.csv/part-00000-73cc26d7-af8b-40b9-b9d1-6e3f028dfd54-c000.csv
# Reading dq-analytics-657082399901-dev/analytics/reports/run_date=2025-11-24/report_joined.csv/part-00000-4ebb808b-43d8-4436-a90c-1b3e7a8b172a-c000.csv
# (     series_id  best_year  summed_value_for_best_year
#  0  PRS30006011     2022.0                      20.500
#  1  PRS30006012     2022.0                      17.100
#  2  PRS30006013     1989.0                     722.957
#  3  PRS30006021     2010.0                      17.700
#  4  PRS30006022     2010.0                      12.400,
#       series_id  period    year  value  population
#  0    series_id  period     NaN    NaN         NaN
#  1  PRS30006011     Q01  1988.0    1.9         NaN
#  2  PRS30006011     Q02  1988.0    2.2         NaN
#  3  PRS30006011     Q03  1988.0    1.9         NaN
#  4  PRS30006011     Q04  1988.0    1.1         NaN)

# %%
summary_bls = (
    df_ts.groupby("series_id")
    .agg(
        min_year=("year", "min"),
        max_year=("year", "max"),
        n_obs=("year", "count"),
        mean_value=("value", "mean"),
    )
    .reset_index()
)

summary_bls.sort_values("n_obs", ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/ops.py:884, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     882 splitter = self._get_splitter(obj, axis=0)
# --> 884 for i, group in enumerate(splitter):
#     885     res = func(group)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1150, in DataSplitter.__iter__(self)
#    1149 def __iter__(self) -> Iterator:
# -> 1150     sdata = self._sorted_data
#    1152     if self.ngroups == 0:
#    1153         # we are inside a generator, rather than raise StopIteration
#    1154         # we merely return signal the end
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1164, in DataSplitter._sorted_data(self)
#    1162 @cache_readonly
#    1163 def _sorted_data(self) -> NDFrameT:
# -> 1164     return self.data.take(self._sort_idx, axis=self.axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/generic.py:4152, in NDFrame.take(self, indices, axis, **kwargs)
#    4148     indices = np.arange(
#    4149         indices.start, indices.stop, indices.step, dtype=np.intp
#    4150     )
# -> 4152 new_data = self._mgr.take(
#    4153     indices,
#    4154     axis=self._get_block_manager_axis(axis),
#    4155     verify=True,
#    4156 )
#    4157 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4158     self, method="take"
#    4159 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/internals/managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/internals/managers.py:680, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     679 if axis == 0:
# --> 680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/internals/managers.py:773, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     771             bp = BlockPlacement(slice(0, sllen))
#     772             return [
# --> 773                 blk.take_nd(
#     774                     slobj,
#     775                     axis=0,
#     776                     new_mgr_locs=bp,
#     777                     fill_value=fill_value,
#     778                 )
#     779             ]
#     781 if sl_type == "slice":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/internals/blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/array_algos/take.py:114, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     110         return arr.take(
#     111             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     112         )
# --> 114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:1377, in ArrowExtensionArray.take(self, indices, allow_fill, fill_value)
#    1374         # return type(self)(pc.fill_null(result, pa.scalar(fill_value)))
#    1375     else:
#    1376         # Nothing to fill
# -> 1377         return type(self)(self._pa_array.take(indices))
#    1378 else:  # allow_fill=False
#    1379     # TODO(ARROW-9432): Treat negative indices as indices from the right.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pyarrow/table.pxi:1083, in pyarrow.lib.ChunkedArray.take()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pyarrow/compute.py:506, in take(data, indices, boundscheck, memory_pool)
#     505 options = TakeOptions(boundscheck=boundscheck)
# --> 506 return call_function('take', [data, indices], options, memory_pool)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pyarrow/_compute.pyx:604, in pyarrow._compute.call_function()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pyarrow/_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Cannot yet unify dictionaries with nulls
#
# The above exception was the direct cause of the following exception:
#
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[12], line 3
#       1 summary_bls = (
#       2     df_ts.groupby("series_id")
# ----> 3     .agg(
#       4         min_year=("year", "min"),
#       5         max_year=("year", "max"),
#       6         n_obs=("year", "count"),
#       7         mean_value=("value", "mean"),
#       8     )
#       9     .reset_index()
#      10 )
#      12 summary_bls.sort_values("n_obs", ascending=False).head(10)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)
#     421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/apply.py:1603, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1598     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1600 with com.temp_setattr(
#    1601     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1602 ):
# -> 1603     result_index, result_data = self.compute_dict_like(
#    1604         op_name, selected_obj, selection, kwargs
#    1605     )
#    1606 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1607 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     493         results += key_data
#     494 else:
#     495     # key used for column selection and output
# --> 496     results = [
#     497         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498         for key, how in func.items()
#     499     ]
#     500     keys = list(func.keys())
#     502 return keys, results
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/apply.py:497, in <listcomp>(.0)
#     493         results += key_data
#     494 else:
#     495     # key used for column selection and output
#     496     results = [
# --> 497         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498         for key, how in func.items()
#     499     ]
#     500     keys = list(func.keys())
#     502 return keys, results
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/generic.py:257, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255 kwargs["engine"] = engine
#     256 kwargs["engine_kwargs"] = engine_kwargs
# --> 257 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258 if relabeling:
#     259     # columns is not narrowed by mypy from relabeling flag
#     260     assert columns is not None  # for mypy
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/generic.py:362, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     360     for idx, (name, func) in enumerate(arg):
#     361         key = base.OutputKey(label=name, position=idx)
# --> 362         results[key] = self.aggregate(func, *args, **kwargs)
#     364 if any(isinstance(x, DataFrame) for x in results.values()):
#     365     from pandas import concat
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/generic.py:249, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     247     if engine_kwargs is not None:
#     248         kwargs["engine_kwargs"] = engine_kwargs
# --> 249     return getattr(self, func)(*args, **kwargs)
#     251 elif isinstance(func, abc.Iterable):
#     252     # Catch instances of lists / tuples
#     253     # but not the class list / tuple itself.
#     254     func = maybe_mangle_lambdas(func)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:3268, in GroupBy.min(self, numeric_only, min_count, engine, engine_kwargs)
#    3260     return self._numba_agg_general(
#    3261         grouped_min_max,
#    3262         executor.identity_dtype_mapping,
#    (...)
#    3265         is_max=False,
#    3266     )
#    3267 else:
# -> 3268     return self._agg_general(
#    3269         numeric_only=numeric_only,
#    3270         min_count=min_count,
#    3271         alias="min",
#    3272         npfunc=np.min,
#    3273     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1907, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1897 @final
#    1898 def _agg_general(
#    1899     self,
#    (...)
#    1905     **kwargs,
#    1906 ):
# -> 1907     result = self._cython_agg_general(
#    1908         how=alias,
#    1909         alt=npfunc,
#    1910         numeric_only=numeric_only,
#    1911         min_count=min_count,
#    1912         **kwargs,
#    1913     )
#    1914     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2001, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1998     return result
#    2000 assert alt is not None
# -> 2001 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/de_env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1947, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1945     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1946     # preserve the kind of exception that raised
# -> 1947     raise type(err)(msg) from err
#    1949 dtype = ser.dtype
#    1950 if dtype == object:
#
# ArrowInvalid: agg function failed [how->min,dtype->dictionary<values=int32, indices=int32, ordered=0>[pyarrow]]
